# %% [markdown]
# # Azure ML quickstart
# ## 1. Create local run environment
# ```powershell
#  pip install azureml-core azureml-telemetry azureml-widgets azureml-dataset-runtime
# ```
# ## 2. Create Azure Compute Cluster
# ![AzureML Create compute cluster](./../img/create_cluster.png "Create compute cluster")
#
# ![AzureML Naming convention](./../img/cluster_name.png "Cluster naming convention")
#
# ## 3. Upload your dataset (if not present)
# Try to do it in separate script.

# %%
from azureml.core import Workspace
from azureml.core.authentication import InteractiveLoginAuthentication
from azureml.core.datastore import Datastore

# %% [markdown]
# 1. you need to connect to workspace
#     - Ideally download the `config.json` and load it with it.
#     - ![config.json](./../img/config.png "config.json for connecting to AML")
#     - Use `InteractiveLoginAuthentification` to automatically redirect to web browser and login to Azure ML. (Use own credentials ;)

# %%
ws = Workspace.from_config(path='azure_config.json', auth=InteractiveLoginAuthentication())

# %% [markdown]
# 2. get the default Datastore (you don't have privileges to any other)

# %%
datastore = Datastore.get_default(ws)

# %% [markdown]
# 3. Get the list of all files you want to upload
#     - there is no other way, the datasets in AzureML are only files and using the full path in their name works as the directory tree
#     - __Be extra careful with the relative_root and target_path__
#        - for example my upload that loadst data from directory "data/..." and uploads them into "datasets/TexDat"
#        - `relative_root` is the common path *parent directories* in the data names where you want your data to be translated under the `target_path`

# %%
import os
print(os.getcwd())
# Out:
# C:\Repositories\PythonRepos\TexSim2018\scripts

# %%
files_fo = os.listdir('../dataDTD/images/')
files_fo = list(map(lambda x : os.path.join('../dataDTD/images/', x), files_fo))
files_im = []
for f in files_fo:
    files_im += [os.path.join(f, im) for im in os.listdir(f)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d30f99331d6a> in <module>
# ----> 1 files_fo = os.listdir('../dataDTD/images/')
#       2 files_fo = list(map(lambda x : os.path.join('../dataDTD/images/', x), files_fo))
#       3 files_im = []
#       4 for f in files_fo:
#       5     files_im += [os.path.join(f, im) for im in os.listdir(f)]
#
# NameError: name 'os' is not defined

# %%
len(files_im)
# Out:
# 5641

# %%
files_la = os.listdir('../dataDTD/labels/')
files_la = list(map(lambda x : os.path.join('../dataDTD/labels/', x), files_la))
files = files_im+files_la

# %%
datastore.upload_files(files=files, relative_root='../dataDTD', target_path='datasets/DTD')

# %%
files_tr = os.listdir('../data/train')
files_tr = list(map(lambda x : os.path.join('../data/train/', x), files_tr))
files_v = os.listdir('../data/val')
files_v = list(map(lambda x : os.path.join('../data/val/', x), files_v))
files_te = os.listdir('../data/test')
files_te = list(map(lambda x : os.path.join('../data/test/', x), files_te))
files = files_tr+files_v+files_te

datastore.upload_files(files=files, relative_root='../data', target_path='datasets/TexDat')

# %% [markdown]
# ## 4. Create Dataset
# For me personally, it was easier to create Dataset manually in Studio than to use the API...
#
# ![Create dataset](./../img/create_dataset.gif "Create Dataset, ..., File, Blob, ..., Path to files/**")

# %% [markdown]
# ## 5. Create Control run script
# There are several tutorials in the AzureML documentation... maybe most useful are these few:
# 1. [Hello World](https://docs.microsoft.com/en-us/azure/machine-learning/tutorial-1st-experiment-hello-world)
# 2. [Train your ML network](https://docs.microsoft.com/en-us/azure/machine-learning/tutorial-1st-experiment-sdk-train)
# 3. [Use own data](https://docs.microsoft.com/en-us/azure/machine-learning/tutorial-1st-experiment-bring-data)
# 4. [Create SW Environment](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-use-environments)
# 5. [Where & How to save outputs from your training](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-save-write-experiment-files)
#
#
# ### 5.1. Let's start here with useful imports
# If you are starting from here and don't have all the imports from previous steps, then here you are...

# %%
import os
import azureml.core
from azureml.core import Workspace
from azureml.core import Experiment
from azureml.core.environment import Environment
from azureml.core import ScriptRunConfig
from azureml.core import Dataset
from azureml.data.datapath import DataPath
from azureml.core.authentication import InteractiveLoginAuthentication

print("Azure ML SDK Version: ", azureml.core.VERSION)
# Out:
# Azure ML SDK Version:  1.28.0

# %% [markdown]
# ### 5.2 Don't forget to log in to your workspace
# (usually the authentication is required only the first time)

# %%
ws = Workspace.from_config('azure_config.json', auth=InteractiveLoginAuthentication())
print(ws.name, ws.location, ws.resource_group, sep='\t')
# Out:
# a0047stufiitml01	westeurope	a0047-STUFIIT-ML01

# %% [markdown]
# ### 5.3 Get your created Dataset - for use in training

# %%
dataset = Dataset.get_by_name(workspace=ws, name='DTD')

# %% [markdown]
# ### 5.4 Pretty much everything is configured by this ScriptRunConfig
# Read the [documentation](https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.core.scriptrunconfig?view=azure-ml-py). <br>
# If you ever wondered, how the Azure runs your scripts - it uploads your `source_directory`. Use `.gitignore` if there is anything not required to run your script, because the whole space for created snapshot is only 300MB including `./outputs`. <br>
# You can [override snapshot size limit](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-save-write-experiment-files#storage-limits-of-experiment-snapshots), though.

# %%
config = ScriptRunConfig(source_directory='../',
                         script='main.py',
                         arguments=['--wandb', "584287ef3bc4e3311465171c04c9525858e97893",
                                    '--data_path', dataset.as_mount()], # This is important how to mount dataset from DataStore
                         compute_target='P100x1-hudec2') # Compute target is your created compute cluster

# %% [markdown]
# ### 5.4 Set the name of your experiment
# ... where all your runs will be aggregated

# %%
experiment = Experiment(workspace=ws, name='VGG-Seminar')

# %% [markdown]
# ### 5.5 Create/Select your required remote environment
# ###### Note1: pip install opencv-python-headless - for standard opencv AzureML returns import error
# ###### Note2: Beware that not all latest libraries are available for AzureML... PyTorch 1.8.0 thankfully is ;)
#
# #### 5.5.1 You can list [curated](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-use-environments#use-a-curated-environment) azure environments
# And select one of already registered environments - if it has all you need for your ML project

# %%
for i,key in enumerate(ws.environments.keys()):
    print(f"{i}.",key)
# Out:
# 0. pt-wandb-env
# 1. tf-wandb-env
# 2. Torch1.8-Opencv-wandb
# 3. Torch1.8-Pillow-wandb
# 4. Salko-Torch
# 5. tf-gpu-sakalik
# 6. AzureML-Triton
# 7. AzureML-sklearn-0.24.1-ubuntu18.04-py37-cpu-inference
# 8. AzureML-tensorflow-1.15-ubuntu18.04-py37-cpu-inference
# 9. AzureML-tensorflow-2.4-ubuntu18.04-py37-cpu-inference
# 10. AzureML-pytorch-1.7-ubuntu18.04-py37-cpu-inference
# 11. AzureML-TensorFlow-2.3-CPU
# 12. AzureML-PyTorch-1.6-GPU
# 13. AzureML-TensorFlow-2.3-GPU
# 14. AzureML-PyTorch-1.6-CPU
# 15. AzureML-tensorflow-2.4-ubuntu18.04-py37-cuda11.0.3-gpu-inference
# 16. AzureML-tensorflow-2.4-ubuntu18.04-py37-cuda11-gpu
# 17. AzureML-pytorch-1.7-ubuntu18.04-py37-cuda11-gpu
# 18. AzureML-DeepSpeed-0.3-GPU
# 19. AzureML-PyTorch-1.3-CPU
# 20. AzureML-xgboost-0.9-ubuntu18.04-py37-cpu-inference
# 21. AzureML-mlflow-ubuntu18.04-py37-cpu-inference
# 22. AzureML-Tutorial
# 23. AzureML-onnxruntime-1.6-ubuntu18.04-py37-cpu-inference
# 24. AzureML-minimal-ubuntu18.04-py37-cpu-inference
# 25. AzureML-sklearn-0.24-ubuntu18.04-py37-cpu
# 26. AzureML-lightgbm-3.2-ubuntu18.04-py37-cpu
# 27. AzureML-tritonserver-21.02-py38-inference
# 28. AzureML-pytorch-1.6-ubuntu18.04-py37-cpu-inference
# 29. AzureML-Minimal
# 30. AzureML-pytorch-1.8-ubuntu18.04-py37-cuda11-gpu
# 31. AzureML-pytorch-1.9-ubuntu18.04-py37-cuda11-gpu
# 32. AzureML-VowpalWabbit-8.8.0

# %% [markdown]
# You can see the libraries included (watch for the counter)

# %%
envs = Environment.list(workspace=ws)
count = 0
for env in envs:
    print("Name",env)
    print("packages", envs[env].python.conda_dependencies.serialize_to_string())
    count += 1
    if count == 3:
        break
# Out:
# Name pt-wandb-env
# packages channels:
# - conda-forge
# - anaconda
# dependencies:
# - python=3.6.2
# - scipy
# - scikit-image
# - scikit-learn
# - numpy
# - pandas
# - pip:
#   - azureml-defaults
#   - azureml-core
#   - azureml-dataset-runtime
#   - wandb
#   - Pillow
#   - torch==1.6.0
#   - torchvision==0.7.0
# name: azureml_ab95fef37536a3cdc05badd51f080bd5
#
# Name tf-wandb-env
# packages channels:
# - conda-forge
# - anaconda
# dependencies:
# - python=3.6.2
# - scipy
# - scikit-image
# - scikit-learn
# - numpy
# - pandas
# - pip:
#   - azureml-core
#   - azureml-dataset-runtime
#   - tensorflow-gpu==2.2.0
#   - wandb
#   - Pillow
# name: azureml_fa25278502cdb61f88f71980f535b1b5
#
# Name Torch1.8-Opencv-wandb
# packages channels:
# - anaconda
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - wandb>=0.10.30
#   - torch>=1.8.1
#   - torch-summary
#   - numpy>=1.19.3
#   - opencv-python-headless>=4.4.0.46
#   - matplotlib>=3.3.3
#   - tqdm==4.60.0
#   - azureml-core==1.28.0
# - pip
# name: azureml_f0c6c9b29580db4284cca92a362fa8da

# %% [markdown]
# #### 5.5.2 Or you can create your own environment
# .. from scratch using conda dependencies or pip [requirements.txt](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-use-environments#use-conda-dependencies-or-pip-requirements-files)
# .. dont't forget to register it to workspace
# .. you can allow Docker for quicker loading...

# %%
azureml.core.runconfig.DockerConfiguration(use_docker=True)
env = Environment.from_pip_requirements(name='Torch1.8-Opencv-wandb', file_path='../requirements.txt')
env.register(workspace=ws)
# Out:
# {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210301.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "enabled": false,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "Torch1.8-Opencv-wandb",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "anaconda",
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.6.2",
#                 {
#                     "pip": [
#                         "wandb>=0.10.30",
#                         "torch>=1.8.1",
#                         "torch-summary",
#                         "numpy>=1.19.3",
#                         "opencv-python-headless>=4.4.0.46",
#                         "matplotlib>=3.3.3",
#                         "tqdm==4.60.0",
#                         "azureml-core==1.28.0"
#                     ]
#                 },
#                 "pip"
#             ],
#             "name": "azureml_f0c6c9b29580db4284cca92a362fa8da"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": "4"
# }

# %% [markdown]
# #### 5.5.3. Select the one environment you desire
# Or actually once you create your required env and register it, this is the only thing you will be calling `Environment.get(...)`

# %%
env = Environment.get(workspace=ws, name='Torch1.8-Opencv-wandb')

# %%
env.list(ws)
# Out:
# {'pt-wandb-env': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": true,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "pt-wandb-env",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge",
#                  "anaconda"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  "scipy",
#                  "scikit-image",
#                  "scikit-learn",
#                  "numpy",
#                  "pandas",
#                  {
#                      "pip": [
#                          "azureml-defaults",
#                          "azureml-core",
#                          "azureml-dataset-runtime",
#                          "wandb",
#                          "Pillow",
#                          "torch==1.6.0",
#                          "torchvision==0.7.0"
#                      ]
#                  }
#              ],
#              "name": "azureml_ab95fef37536a3cdc05badd51f080bd5"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "4"
#  },
#  'tf-wandb-env': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": true,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "tf-wandb-env",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge",
#                  "anaconda"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  "scipy",
#                  "scikit-image",
#                  "scikit-learn",
#                  "numpy",
#                  "pandas",
#                  {
#                      "pip": [
#                          "azureml-core",
#                          "azureml-dataset-runtime",
#                          "tensorflow-gpu==2.2.0",
#                          "wandb",
#                          "Pillow"
#                      ]
#                  }
#              ],
#              "name": "azureml_fa25278502cdb61f88f71980f535b1b5"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "3"
#  },
#  'Torch1.8-Opencv-wandb': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210301.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "Torch1.8-Opencv-wandb",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "wandb>=0.10.30",
#                          "torch>=1.8.1",
#                          "torch-summary",
#                          "numpy>=1.19.3",
#                          "opencv-python-headless>=4.4.0.46",
#                          "matplotlib>=3.3.3",
#                          "tqdm==4.60.0",
#                          "azureml-core==1.28.0"
#                      ]
#                  },
#                  "pip"
#              ],
#              "name": "azureml_f0c6c9b29580db4284cca92a362fa8da"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "4"
#  },
#  'AzureML-tensorflow-2.4-ubuntu18.04-py37-cuda11-gpu': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/openmpi4.1.0-cuda11.0.3-cudnn8-ubuntu18.04:20210615.v1\n\nENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/tensorflow-2.4\n\n# Create conda environment\nRUN conda create -p $AZUREML_CONDA_ENVIRONMENT_PATH \\\n    python=3.7 pip=20.2.4\n\n# Prepend path to AzureML conda environment\nENV PATH $AZUREML_CONDA_ENVIRONMENT_PATH/bin:$PATH\n\n# Install pip dependencies\nRUN HOROVOD_WITH_TENSORFLOW=1 \\\n    pip install 'matplotlib>=3.3,<3.4' \\\n                'psutil>=5.8,<5.9' \\\n                'tqdm>=4.59,<4.60' \\\n                'pandas>=1.1,<1.2' \\\n                'scipy>=1.5,<1.6' \\\n                'numpy>=1.10,<1.20' \\\n                'azureml-core==1.31.0' \\\n                'azureml-defaults==1.31.0' \\\n                'azureml-mlflow==1.31.0' \\\n                'azureml-telemetry==1.31.0' \\\n                'tensorboard==2.4.0' \\\n                'tensorflow-gpu==2.4.1' \\\n                'onnxruntime-gpu>=1.7,<1.8' \\\n                'horovod[tensorflow-gpu]==0.21.3'\n\n# This is needed for mpi to locate libpython\nENV LD_LIBRARY_PATH $AZUREML_CONDA_ENVIRONMENT_PATH/lib:$LD_LIBRARY_PATH",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-tensorflow-2.4-ubuntu18.04-py37-cuda11-gpu",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "4"
#  },
#  'AzureML-tensorflow-1.15-ubuntu18.04-py37-cpu-inference': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/tensorflow-1.15-ubuntu18.04-py37-cpu-inference:20210622.v2",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-tensorflow-1.15-ubuntu18.04-py37-cpu-inference",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "3"
#  },
#  'AzureML-sklearn-0.24-ubuntu18.04-py37-cuda11-gpu': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/openmpi4.1.0-cuda11.0.3-cudnn8-ubuntu18.04:20210615.v1\n\nENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/sklearn-0.24.1\n\n# Create conda environment\nRUN conda create -p $AZUREML_CONDA_ENVIRONMENT_PATH \\\n    python=3.7 pip=20.2.4\n\n# Prepend path to AzureML conda environment\nENV PATH $AZUREML_CONDA_ENVIRONMENT_PATH/bin:$PATH\n\n# Install pip dependencies\nRUN pip install 'matplotlib>=3.3,<3.4' \\\n                'psutil>=5.8,<5.9' \\\n                'tqdm>=4.59,<4.60' \\\n                'pandas>=1.1,<1.2' \\\n                'scipy>=1.5,<1.6' \\\n                'numpy>=1.10,<1.20' \\\n                'azureml-core==1.31.0' \\\n                'azureml-defaults==1.31.0' \\\n                'azureml-mlflow==1.31.0' \\\n                'azureml-telemetry==1.31.0' \\\n                'scikit-learn==0.24.1'\n\n# This is needed for mpi to locate libpython\nENV LD_LIBRARY_PATH $AZUREML_CONDA_ENVIRONMENT_PATH/lib:$LD_LIBRARY_PATH\n",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-sklearn-0.24-ubuntu18.04-py37-cuda11-gpu",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "4"
#  },
#  'AzureML-tensorflow-2.4-ubuntu18.04-py37-cpu-inference': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/tensorflow-2.4-ubuntu18.04-py37-cpu-inference:20210622.v2",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-tensorflow-2.4-ubuntu18.04-py37-cpu-inference",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "3"
#  },
#  'AzureML-tensorflow-2.4-ubuntu18.04-py37-cuda11.0.3-gpu-inference': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/tensorflow-2.4-ubuntu18.04-py37-cuda11.0.3-gpu-inference:20210622.v2",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-tensorflow-2.4-ubuntu18.04-py37-cuda11.0.3-gpu-inference",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "3"
#  },
#  'AzureML-pytorch-1.7-ubuntu18.04-py37-cpu-inference': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/pytorch-1.7-ubuntu18.04-py37-cpu-inference:20210622.v2",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-pytorch-1.7-ubuntu18.04-py37-cpu-inference",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "3"
#  },
#  'AzureML-pytorch-1.7-ubuntu18.04-py37-cuda11-gpu': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/openmpi4.1.0-cuda11.0.3-cudnn8-ubuntu18.04:20210615.v1\n\nENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/pytorch-1.7\n\n# Create conda environment\nRUN conda create -p $AZUREML_CONDA_ENVIRONMENT_PATH \\\n    python=3.7 \\\n    pip=20.2.4 \\\n    pytorch=1.7.1 \\\n    torchvision=0.8.2 \\\n    torchaudio=0.7.2 \\\n    cudatoolkit=11.0 \\\n    nvidia-apex=0.1.0 \\\n    -c anaconda -c pytorch -c conda-forge\n\n# Prepend path to AzureML conda environment\nENV PATH $AZUREML_CONDA_ENVIRONMENT_PATH/bin:$PATH\n\n# Install pip dependencies\nRUN HOROVOD_WITH_PYTORCH=1 \\\n    pip install 'matplotlib>=3.3,<3.4' \\\n                'psutil>=5.8,<5.9' \\\n                'tqdm>=4.59,<4.60' \\\n                'pandas>=1.1,<1.2' \\\n                'scipy>=1.5,<1.6' \\\n                'numpy>=1.10,<1.20' \\\n                'azureml-core==1.31.0' \\\n                'azureml-defaults==1.31.0' \\\n                'azureml-mlflow==1.31.0' \\\n                'azureml-telemetry==1.31.0' \\\n                'tensorboard==2.4.0' \\\n                'tensorflow-gpu==2.4.1' \\\n                'onnxruntime-gpu>=1.7,<1.8' \\\n                'horovod[pytorch]==0.21.3' \\\n                'future==0.17.1'\n\n# This is needed for mpi to locate libpython\nENV LD_LIBRARY_PATH $AZUREML_CONDA_ENVIRONMENT_PATH/lib:$LD_LIBRARY_PATH\n",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-pytorch-1.7-ubuntu18.04-py37-cuda11-gpu",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "4"
#  },
#  'AzureML-sklearn-0.24.1-ubuntu18.04-py37-cpu-inference': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/sklearn-0.24.1-ubuntu18.04-py37-cpu-inference:20210622.v2",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-sklearn-0.24.1-ubuntu18.04-py37-cpu-inference",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "3"
#  },
#  'AzureML-minimal-ubuntu18.04-py37-cpu-inference': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/minimal-ubuntu18.04-py37-cpu-inference:20210622.v2",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-minimal-ubuntu18.04-py37-cpu-inference",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "3"
#  },
#  'AzureML-onnxruntime-1.6-ubuntu18.04-py37-cpu-inference': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/onnxruntime-1.6-ubuntu18.04-py37-cpu-inference:20210622.v2",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-onnxruntime-1.6-ubuntu18.04-py37-cpu-inference",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "3"
#  },
#  'AzureML-xgboost-0.9-ubuntu18.04-py37-cpu-inference': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/xgboost-0.9-ubuntu18.04-py37-cpu-inference:20210622.v2",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-xgboost-0.9-ubuntu18.04-py37-cpu-inference",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "3"
#  },
#  'AzureML-TensorFlow-2.3-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210615.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-TensorFlow-2.3-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  "pip=20.2.4",
#                  {
#                      "pip": [
#                          "azureml-core==1.31.0",
#                          "azureml-defaults==1.31.0",
#                          "azureml-telemetry==1.31.0",
#                          "azureml-train-restclients-hyperdrive==1.31.0",
#                          "azureml-train-core==1.31.0",
#                          "tensorflow==2.3.0",
#                          "cmake==3.18.2",
#                          "horovod==0.21.3"
#                      ]
#                  }
#              ],
#              "name": "azureml_43d62bd1f7f5e9e338f97a412d6caef9"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "17"
#  },
#  'AzureML-Triton': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/aml-triton:20210402.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-Triton",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.7.9",
#                  {
#                      "pip": [
#                          "azureml-core==1.31.0",
#                          "azureml-defaults[async]",
#                          "azureml-contrib-services==1.31.0",
#                          "numpy",
#                          "inference-schema[numpy-support]",
#                          "grpcio-tools",
#                          "geventhttpclient",
#                          "https://developer.download.nvidia.com/compute/redist/tritonclient/tritonclient-2.7.0-py3-none-manylinux1_x86_64.whl"
#                      ]
#                  }
#              ],
#              "name": "azureml_8079fb495625af2accc027bb826b1ee6"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "19"
#  },
#  'AzureML-PyTorch-1.6-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu16.04:20210531.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-PyTorch-1.6-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  "pip=20.2.4",
#                  {
#                      "pip": [
#                          "azureml-core==1.31.0",
#                          "azureml-defaults==1.31.0",
#                          "azureml-telemetry==1.31.0",
#                          "azureml-train-restclients-hyperdrive==1.31.0",
#                          "azureml-train-core==1.31.0",
#                          "cmake==3.18.2",
#                          "torch==1.6.0",
#                          "torchvision==0.5.0",
#                          "mkl==2018.0.3",
#                          "horovod==0.21.3",
#                          "tensorboard==1.14.0",
#                          "future==0.17.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_72b1777eb7033379da64be7828f5c24a"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "21"
#  },
#  'AzureML-PyTorch-1.6-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.2-cudnn7-ubuntu18.04:20210615.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE",
#          "NCCL_TREE_THRESHOLD": "0"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-PyTorch-1.6-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  "pip=20.2.4",
#                  {
#                      "pip": [
#                          "azureml-core==1.31.0",
#                          "azureml-defaults==1.31.0",
#                          "azureml-telemetry==1.31.0",
#                          "azureml-train-restclients-hyperdrive==1.31.0",
#                          "azureml-train-core==1.31.0",
#                          "cmake==3.18.2",
#                          "torch==1.6.0",
#                          "torchvision==0.5.0",
#                          "mkl==2018.0.3",
#                          "horovod==0.21.3",
#                          "tensorboard==1.14.0",
#                          "future==0.17.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_72b1777eb7033379da64be7828f5c24a"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "20"
#  },
#  'AzureML-TensorFlow-2.3-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04:20210615.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-TensorFlow-2.3-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  "pip=20.2.4",
#                  {
#                      "pip": [
#                          "azureml-core==1.31.0",
#                          "azureml-defaults==1.31.0",
#                          "azureml-telemetry==1.31.0",
#                          "azureml-train-restclients-hyperdrive==1.31.0",
#                          "azureml-train-core==1.31.0",
#                          "tensorflow-gpu==2.3.0",
#                          "cmake==3.18.2",
#                          "horovod==0.21.3"
#                      ]
#                  }
#              ],
#              "name": "azureml_85e38588c83304d153a71fffd4afe3a4"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "15"
#  },
#  'AzureML-DeepSpeed-0.3-GPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04\nENV DS_BUILD_OPS=1",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": true,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE",
#          "NCCL_TREE_THRESHOLD": "0"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-DeepSpeed-0.3-GPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "pytorch",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  "cudatoolkit-dev=10.1.243",
#                  "cudatoolkit=10.1",
#                  "pytorch==1.6.0",
#                  "torchvision==0.7.0",
#                  "gxx_linux-64",
#                  "pip<=20.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.31.0",
#                          "azureml-defaults==1.31.0",
#                          "azureml-telemetry==1.31.0",
#                          "azureml-train-restclients-hyperdrive==1.31.0",
#                          "azureml-train-core==1.31.0",
#                          "azureml-mlflow==1.31.0",
#                          "azureml-dataprep",
#                          "cmake==3.18.2",
#                          "mkl==2018.0.3",
#                          "tensorboard==1.14.0",
#                          "future==0.17.1",
#                          "matplotlib",
#                          "boto3",
#                          "h5py",
#                          "sklearn",
#                          "scipy",
#                          "pillow",
#                          "tqdm",
#                          "cupy-cuda101",
#                          "mpi4py",
#                          "deepspeed==0.3.11"
#                      ]
#                  }
#              ],
#              "name": "azureml_ce49b5dfdac368c6ffb2ea96f3ecfc1c"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "13"
#  },
#  'AzureML-VowpalWabbit-8.8.0': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04\nRUN apt-get update && apt-get install -y --no-install-recommends apt-utils software-properties-common build-essential libboost-all-dev zlib1g-dev cmake && pip install --upgrade pip\nRUN git clone --branch 8.8.0 --recursive https://github.com/VowpalWabbit/vowpal_wabbit.git && cd vowpal_wabbit && mkdir build && cd build && cmake .. -DCMAKE_BUILD_TYPE=Release -DBUILD_TESTS=OFF -DVW_INSTALL=ON -DBUILD_PYTHON=ON -DPY_VERSION=3.6.2 && make install && cd .. && pip install .",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": true,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-VowpalWabbit-8.8.0",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.19.0",
#                          "azureml-defaults==1.19.0",
#                          "azureml-dataset-runtime[fuse,pandas]"
#                      ]
#                  }
#              ],
#              "name": "azureml_769be4b756b756954fa484d1287d5153"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "32"
#  },
#  'AzureML-PyTorch-1.3-CPU': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-PyTorch-1.3-CPU",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  "pip=20.2.4",
#                  {
#                      "pip": [
#                          "azureml-core==1.21.0.post1",
#                          "azureml-defaults==1.21.0",
#                          "azureml-telemetry==1.21.0",
#                          "azureml-train-restclients-hyperdrive==1.21.0",
#                          "azureml-train-core==1.21.0",
#                          "torch==1.3",
#                          "torchvision==0.4.1",
#                          "mkl==2018.0.3",
#                          "horovod==0.18.1",
#                          "tensorboard==1.14.0",
#                          "future==0.17.1"
#                      ]
#                  }
#              ],
#              "name": "azureml_a02f4fa469cd8066bd6e2f219433318d"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "40"
#  },
#  'AzureML-lightgbm-3.2-ubuntu18.04-py37-cpu': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210615.v1\n\nENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/lightgbm\n\n# Create conda environment\nRUN conda create -p $AZUREML_CONDA_ENVIRONMENT_PATH \\\n    python=3.7 pip=20.2.4\n\n# Prepend path to AzureML conda environment\nENV PATH $AZUREML_CONDA_ENVIRONMENT_PATH/bin:$PATH\n\n# Install pip dependencies\nRUN HOROVOD_WITH_TENSORFLOW=1 \\\n    pip install 'matplotlib>=3.3,<3.4' \\\n                'psutil>=5.8,<5.9' \\\n                'tqdm>=4.59,<4.60' \\\n                'pandas>=1.1,<1.2' \\\n                'numpy>=1.10,<1.20' \\\n                'scipy~=1.5.0' \\\n                'scikit-learn~=0.24.1' \\\n                'xgboost~=1.4.0' \\\n                'lightgbm~=3.2.0' \\\n                'dask~=2021.6.0' \\\n                'distributed~=2021.6.0' \\\n                'dask-ml~=1.9.0' \\\n                'adlfs~=0.7.0' \\\n                'azureml-core==1.31.0' \\\n                'azureml-defaults==1.31.0' \\\n                'azureml-mlflow==1.31.0' \\\n                'azureml-telemetry==1.31.0'\n\n# This is needed for mpi to locate libpython\nENV LD_LIBRARY_PATH $AZUREML_CONDA_ENVIRONMENT_PATH/lib:$LD_LIBRARY_PATH",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-lightgbm-3.2-ubuntu18.04-py37-cpu",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "2"
#  },
#  'AzureML-pytorch-1.6-ubuntu18.04-py37-cpu-inference': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/pytorch-1.6-ubuntu18.04-py37-cpu-inference:20210622.v2",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-pytorch-1.6-ubuntu18.04-py37-cpu-inference",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "3"
#  },
#  'AzureML-mlflow-ubuntu18.04-py37-cpu-inference': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/mlflow-ubuntu18.04-py37-cpu-inference:20210622.v2",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-mlflow-ubuntu18.04-py37-cpu-inference",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "1"
#  },
#  'AzureML-Minimal': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210507.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-Minimal",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.31.0",
#                          "azureml-defaults==1.31.0"
#                      ]
#                  }
#              ],
#              "name": "azureml_0f94df69ebbfa67ae035f4e120a09e84"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "55"
#  },
#  'AzureML-tritonserver-21.02-py38-inference': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": "FROM mcr.microsoft.com/azureml/tritonserver-21.02-py38-inference:20210525.1",
#          "baseImage": null,
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-tritonserver-21.02-py38-inference",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-defaults==1.31.0"
#                      ]
#                  }
#              ],
#              "name": "project_environment"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": true
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "5"
#  },
#  'AzureML-Tutorial': {
#      "databricks": {
#          "eggLibraries": [],
#          "jarLibraries": [],
#          "mavenLibraries": [],
#          "pypiLibraries": [],
#          "rcranLibraries": []
#      },
#      "docker": {
#          "arguments": [],
#          "baseDockerfile": null,
#          "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210507.v1",
#          "baseImageRegistry": {
#              "address": null,
#              "password": null,
#              "registryIdentity": null,
#              "username": null
#          },
#          "enabled": false,
#          "platform": {
#              "architecture": "amd64",
#              "os": "Linux"
#          },
#          "sharedVolumes": true,
#          "shmSize": null
#      },
#      "environmentVariables": {
#          "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#      },
#      "inferencingStackVersion": null,
#      "name": "AzureML-Tutorial",
#      "python": {
#          "baseCondaEnvironment": null,
#          "condaDependencies": {
#              "channels": [
#                  "anaconda",
#                  "conda-forge"
#              ],
#              "dependencies": [
#                  "python=3.6.2",
#                  {
#                      "pip": [
#                          "azureml-core==1.31.0",
#                          "azureml-defaults==1.31.0",
#                          "azureml-telemetry==1.31.0",
#                          "azureml-train-restclients-hyperdrive==1.31.0",
#                          "azureml-train-core==1.31.0",
#                          "azureml-widgets==1.31.0",
#                          "azureml-pipeline-core==1.31.0",
#                          "azureml-pipeline-steps==1.31.0",
#                          "azureml-opendatasets==1.31.0",
#                          "azureml-automl-core==1.31.0",
#                          "azureml-automl-runtime==1.31.0",
#                          "azureml-train-automl-client==1.31.0",
#                          "azureml-train-automl-runtime==1.31.0",
#                          "azureml-train-automl==1.31.0",
#                          "azureml-train==1.31.0",
#                          "azureml-sdk==1.31.0",
#                          "azureml-interpret==1.31.0",
#                          "azureml-tensorboard==1.31.0",
#                          "azureml-mlflow==1.31.0",
#                          "mlflow",
#                          "sklearn-pandas"
#                      ]
#                  },
#                  "pandas",
#                  "numpy",
#                  "tqdm",
#                  "scikit-learn",
#                  "matplotlib"
#              ],
#              "name": "azureml_489f82068b0f5a9d2c5dd8405ff38c63"
#          },
#          "condaDependenciesFile": null,
#          "interpreterPath": "python",
#          "userManagedDependencies": false
#      },
#      "r": null,
#      "spark": {
#          "packages": [],
#          "precachePackages": true,
#          "repositories": []
#      },
#      "version": "71"
#  }}

# %% [markdown]
# #### 5.5.4. And of course, we need to use the environment

# %%
config.run_config.environment = env

# %% [markdown]
# ## 5.6. Submit your experiment with config to AzureML
# ...and watch it in your jupyter ntb or in azureml studio..

# %%
run = experiment.submit(config)

# %%
aml_url = run.get_portal_url()
print(aml_url)
# Out:
# https://ml.azure.com/runs/VGG-Seminar_1634650538_145688d4?wsid=/subscriptions/bc82dccd-f19d-42cb-9ce3-0d5df33ef086/resourcegroups/a0047-STUFIIT-ML01/workspaces/a0047stufiitml01&tid=5dbf1add-202a-4b8d-815b-bf0fb024e033

# %% [markdown]
# # There is a lot more to do with Azure...
# Like logging for example... <br>
# I did not try it, because I use [wandb](wandb.ai). <br>
#
# ## Important
# To log anything, use AML [Run module](https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.core.run(class)?view=azure-ml-py#azureml_core_Run_get_context) <br>
# To save your model - use `import os` and save it to default directory `./outputs`. Then, you can use `os` calls and also torch/tf calls to save models when you have the correct path
#
# This is where you will find it all: <br>
# ![Runs Outputs](./../img/run_outputs.png)
